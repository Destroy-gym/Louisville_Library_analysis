# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker
import numpy as np

# %%
df = pd.read_csv('files\merged_2.csv', encoding='ISO-8859-1')
df['ISBN'] = df['ISBN'].apply(lambda x: f'{x:.0f}')
pd.set_option('display.float_format', '{:.0f}'.format)
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\destr\AppData\Local\Temp\ipykernel_16880\1376305768.py:1: SyntaxWarning: invalid escape sequence '\m'
#   df = pd.read_csv('files\merged_2.csv', encoding='ISO-8859-1')
#     BibNum                                              Title  \
# 0   707409  Jeff Immelt and the new GE way : innovation, t...
# 1  1341361           McGraw-Hill's American idioms dictionary
# 2   707411  Robin rescues dinner : 52 weeks of quick-fix m...
# 3  1341362  McGraw-Hill's essential ESL grammar : a handbo...
# 4   707411  Robin rescues dinner : 52 weeks of quick-fix m...
#
#                  Author           ISBN  PublicationYear ItemType  \
# 0   Magee, David, 1965-  9780071605878             2009     Book
# 1    Spears, Richard A.  9780071478939             2007     Book
# 2  Miller, Robin, 1964-  9780307451408             2009     Book
# 3         Lester, Mark.  9780071496421             2008     Book
# 4  Miller, Robin, 1964-  9780307451408             2009     Book
#
#       ItemCollection            ItemLocation  ItemPrice  \
# 0  Adult Non-Fiction                    MAIN         26
# 1     ELL Collection  SOUTH CENTRAL REGIONAL         20
# 2  Adult Non-Fiction      SOUTHWEST REGIONAL         20
# 3     ELL Collection  SOUTH CENTRAL REGIONAL         20
# 4  Adult Non-Fiction      SOUTHWEST REGIONAL         20
#
#                ReportDate  ObjectId   ZIP
# 0  2022/07/01 04:00:00+00         1 40203
# 1  2022/07/01 04:00:00+00         2 40219
# 2  2022/07/01 04:00:00+00         3 40272
# 3  2022/07/01 04:00:00+00         4 40219
# 4  2022/07/01 04:00:00+00         5 40272

# %%
df.dtypes
# Out:
# BibNum               int64
# Title               object
# Author              object
# ISBN                object
# PublicationYear      int64
# ItemType            object
# ItemCollection      object
# ItemLocation        object
# ItemPrice          float64
# ReportDate          object
# ObjectId             int64
# ZIP                float64
# dtype: object
